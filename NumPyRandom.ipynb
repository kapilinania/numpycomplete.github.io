# %% [markdown]
# #NumPy Random

# %%
# here we are import random and generate 0 to 100 number between
import numpy as np
from numpy import random

x= random.randint(100)
print(x)
# Out:
# 59

# %%
# random.rand return float between 0 and 1
x= random.rand()
print(x)
# Out:
# 0.04492382469626044

# %% [markdown]
# ###Random Distribution
# Data Distribution is a list of all possible values, and how often each value occurs
#
# We can generate random numbers based on defined probabilities using the choice() method of the random module.
#
# The choice() method allows us to specify the probability for each value.

# %%
#The sum of all probability numbers should be 1.
x = random.choice([5,7,8,100,52,"kapil"], p=[0.3,0.2,0.2,0.,0.0,0.3], size=(100))
print(x)
# Out:
# ['5' '8' '5' 'kapil' 'kapil' 'kapil' 'kapil' '7' 'kapil' 'kapil' '5' '7'
#  '8' '5' 'kapil' '8' '5' 'kapil' 'kapil' '5' 'kapil' 'kapil' '5' '8'
#  'kapil' 'kapil' '7' 'kapil' 'kapil' '7' '7' '5' 'kapil' 'kapil' '8' '5'
#  '7' '8' '5' 'kapil' '5' 'kapil' '7' 'kapil' 'kapil' '5' 'kapil' 'kapil'
#  'kapil' '5' '5' '8' 'kapil' '7' '5' '7' '5' '7' '5' 'kapil' '5' '7'
#  'kapil' '5' '5' '7' '5' '7' '5' '5' '8' '5' '8' '8' '8' '5' '5' '5' '5'
#  'kapil' 'kapil' 'kapil' '5' '8' '5' '5' 'kapil' '5' 'kapil' '5' 'kapil'
#  '7' '7' '8' '7' 'kapil' '8' 'kapil' '7' '8']

# %%
# if we want 2- D array then
x = random.choice([5,7,8,100,52,"kapil"], p=[0.3,0.2,0.2,0.,0.0,0.3], size=(5,5))
print(x)
# Out:
# [['kapil' 'kapil' 'kapil' 'kapil' '8']
#  ['5' '5' '5' '8' '8']
#  ['5' 'kapil' 'kapil' 'kapil' '5']
#  ['kapil' '5' '5' '7' '5']
#  ['8' '5' 'kapil' '8' '7']]

# %% [markdown]
# ###Random Permutations of Elements
# The NumPy Random module provides two methods for this: shuffle() and permutation().

# %%
#Shuffling Arrays
# here we are random shufle element of following array
#method makes changes to the original array.
arr = np.array([4,5,20,10,6,8,0.5,"kapil", True,False])
random.shuffle(arr)
print(arr)
# Out:
# ['0.5' 'kapil' 'False' '8' '10' '4' '5' 'True' '6' '20']

# %%
#Generating Permutation of Arrays
#The permutation() method returns a re-arranged array (and leaves the original array un-changed).
arr = np.array([4,5,20,10,6,8,0.5,"kapil", True,False])
print(random.permutation(arr))
# Out:
# ['8' 'False' '10' 'True' 'kapil' '4' '0.5' '5' '6' '20']

# %%
#we can use seaborn to visualize random distributions
#Import Matplotlib
import matplotlib.pyplot as plt
#import seaborn
import seaborn as sns

# %%
#Plotting a Distplot
arr = np.array([4,5,20,10,6,8,0.5])
random.shuffle(arr)
x= sns.distplot(arr)
plt.show(x)
print(x)
# Out:
# <ipython-input-36-9849a19ada91>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   x= sns.distplot(arr)
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ##Normal Distribution
# The Normal Distribution is one of the most important distributions.
#
# The Normal Distribution is one of the most important distributions.
#
# It fits the probability distribution of many events, eg. IQ Scores, Heartbeat etc.
#
# Use the random.normal() method to get a Normal Data Distribution.
#
# It has three parameters:
#
# loc - (Mean) where the peak of the bell exists.
#
# scale - (Standard Deviation) how flat the graph distribution should be.
#
# size - The shape of the returned array.
#
# iiska use hum wha karta hia jana probability nikalini hoo ki 12th ka result is bt kiya hoga like that

# %%
#random normal distribution of size 2*3
x = random.normal(size=(2,3))
print(x)
# Out:
# [[-0.87338857  0.2580727   0.7085452 ]
#  [-0.47521354 -0.17125074  0.27304433]]

# %%
#normal distribution of size id 3*3 and , mean =2 and standered deviation=2
x= random.normal(loc=2, scale=2, size=(3,3))
print(x)
# Out:
# [[ 1.87155472 -0.59772058  0.96962252]
#  [ 2.93200847  4.15021712  4.50256936]
#  [ 4.01524114 -0.92088625  0.92257964]]

# %%
#Visualization of Normal Distribution
# it is only 1-D Array
sns.distplot(random.normal(size=200), label='Data 1', hist=False, color='green',hist_kws={'edgecolor': 'black'}, kde_kws={'linestyle': '--'})
sns.distplot(random.normal(size=500), label='Data 2', hist=False, color='red',hist_kws={'edgecolor': 'orange'}, kde_kws={'linestyle': 'dotted'})

plt.show
plt.title('Random Distribution Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.legend()
# Out:
# <ipython-input-64-383f830a7b3b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=200), label='Data 1', hist=False, color='green',hist_kws={'edgecolor': 'black'}, kde_kws={'linestyle': '--'})
# <ipython-input-64-383f830a7b3b>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#Visualization of Normal Distribution
# it is only 2-D Array
data1 = np.random.normal(loc=3, scale=15, size=(3, 3)).flatten()
data2 = np.random.normal(loc=10, scale=50, size=(3, 3)).flatten()

sns.distplot(data1, label='Data 1', hist=False, color='green', hist_kws={'edgecolor': 'black'}, kde_kws={'linestyle': '--'})
sns.distplot(data2, label='Data 2', hist=False, color='red', hist_kws={'edgecolor': 'orange'}, kde_kws={'linestyle': 'dotted'})

plt.title('Random Distribution Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.legend()

plt.show()
# Out:
# <ipython-input-67-f67731094043>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1, label='Data 1', hist=False, color='green', hist_kws={'edgecolor': 'black'}, kde_kws={'linestyle': '--'})
# <ipython-input-67-f67731094043>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#Visualization of Normal Distribution
# it is only 3-D Array
data1 = np.random.normal(loc=15, scale=15, size=(3, 3, 3)).flatten()
data2 = np.random.normal(loc=10, scale=50, size=(3, 3, 3)).flatten()

# Reshape the 3D data to 1D arrays
data1 = data1.flatten()
data2 = data2.flatten()

# Create 2D KDE plots for each slice
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.kdeplot(data1, label='Data 1', color='green', ax=axes[0])
sns.kdeplot(data2, label='Data 2', color='red', ax=axes[1])

axes[0].set_title('Data 1 KDE Plot')
axes[1].set_title('Data 2 KDE Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.legend()

plt.show()

# %% [markdown]
# ##Binomial Distribution
# Binomial Distribution is a Discrete Distribution.
#
# It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails.
#
# It has three parameters:
#
# n - number of trials.
#
# p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each).
#
# size - The shape of the returned array.

# %%
#Here we are 10 trails of coin
x=random.binomial(n=10, p=0.5, size=10)
print(x)
# Out:
# [5 4 7 1 6 4 6 5 4 6]

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=True)
plt.show()
# Out:
# <ipython-input-80-5152e9581c2e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=True)

# %%
#Difference Between Normal and Binomial Distribution
#The main difference is that normal distribution is continous whereas binomial is discrete
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=True, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=True,  label='binomial')
plt.legend()
plt.show()
# Out:
# <ipython-input-87-64b9a7bb5eb7>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=True, label='normal')
# <ipython-input-87-64b9a7bb5eb7>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ##Poisson Distribution
# Poisson Distribution is a Discrete Distribution.
#
# It estimates how many times an event can happen in a specified time. e.g. If someone eats twice a day what is the probability he will eat thrice?
#
# It has two parameters:
#
# lam - rate or known number of occurrences e.g. 2 for above problem.
#
# size - The shape of the returned array.

# %%
x=random.poisson(lam=2, size=10)
print(x)
# Out:
# [3 2 1 1 2 1 1 4 2 0]

# %%
sns.distplot(random.poisson(lam=2, size=1000), kde=False)

plt.show()
# Out:
# <ipython-input-89-da7683d3ea23>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False)

# %%
# Difference Between Normal and Poisson , binomial Distribution
#Normal distribution is continuous whereas poisson is discrete.
sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson')
plt.legend()
plt.show()
# Out:
# <ipython-input-93-455dd7b9e548>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
# <ipython-input-93-455dd7b9e548>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ##Uniform Distribution
# Used to describe probability where every event has equal chances of occuring.
#
# E.g. Generation of random numbers.
#
# It has three parameters:
#
# a - lower bound - default 0 .0.
#
# b - upper bound - default 1.0.
#
# size - The shape of the returned array.

# %%
x=random.uniform(size=(2,3))
print(x)
# Out:
# [[0.7290961  0.240586   0.53901984]
#  [0.30513895 0.15460231 0.92180814]]

# %%
#Visualization of Uniform Distribution
sns.distplot(random.uniform(size=1000), hist=False)
plt.show()
# Out:
# <ipython-input-98-6598de826d6d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=1000), hist=False)

# %% [markdown]
# ##Logistic Distribution
# Logistic Distribution is used to describe growth.
#
# Used extensively in machine learning in logistic regression, neural networks etc.
#
# It has three parameters:
#
# loc - mean, where the peak is. Default 0.
#
# scale - standard deviation, the flatness of distribution. Default 1.
#
# size - The shape of the returned array.

# %%
from numpy import random
x= random.logistic(loc=1, scale=2, size=(2,3))
print(x)
# Out:
# [[ 1.47842496 -0.1280577   2.23332901]
#  [-0.60914577 -0.61805781 -3.40377485]]

# %%
#Visualization of Logistic Distribution
sns.distplot(random.logistic(loc=1, scale=2, size=(2,3)), hist=False)
plt.show()
# Out:
# <ipython-input-106-d6ad5274548d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(loc=1, scale=2, size=(2,3)), hist=False)

# %% [markdown]
# #Difference Between Logistic and Normal Distribution
# Both distributions are near identical, but logistic distribution has more area under the tails, meaning it represents more possibility of occurrence of an event further away from mean.
#
# For higher value of scale (standard deviation) the normal and logistic distributions are near identical apart from the peak.

# %%
sns.distplot(random.normal(scale=2, size=1000), hist=False, label='normal')
sns.distplot(random.logistic(size=1000), hist=False, label='logistic')
plt.legend()
plt.show()
# Out:
# <ipython-input-108-4a9d8b3dc472>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(scale=2, size=1000), hist=False, label='normal')
# <ipython-input-108-4a9d8b3dc472>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# #Multinomial Distribution
# Multinomial distribution is a generalization of binomial distribution.
#
# It describes outcomes of multi-nomial scenarios unlike binomial where scenarios must be only one of two. e.g. Blood type of a population, dice roll outcome.
#
# It has three parameters:
#
# n - number of possible outcomes (e.g. 6 for dice roll).
#
# pvals - list of probabilties of outcomes (e.g. [1/6, 1/6, 1/6, 1/6, 1/6, 1/6] for dice roll).
#
# size - The shape of the returned array.

# %%
x= random.multinomial(n=6, pvals=[1/6,1/6,1/6,1/6,1/6,1/6])
print(x)
# Out:
# [0 1 3 1 0 1]

# %%
# it is almost normal distribution
sns.distplot(random.normal(scale=2, size=1000), hist=False, label='normal')
sns.distplot(random.multinomial(n=6, pvals=[1/6,1/6,1/6,1/6,1/6,1/6]), hist=False, label='multinomial')
plt.legend()
plt.show()
# Out:
# <ipython-input-115-a526499cb532>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(scale=2, size=1000), hist=False, label='normal')
# <ipython-input-115-a526499cb532>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# #Exponential Distribution
# Exponential distribution is used for describing time till next event e.g. failure/success etc.
#
# It has two parameters:
#
# scale - inverse of rate ( see lam in poisson distribution ) defaults to 1.0.
#
# size - The shape of the returned array.

# %%
x = random.exponential(scale=2, size=(2, 3))
print(x)
# Out:
# [[3.08293036 4.58277352 1.32742138]
#  [0.80759556 3.41939546 1.4700699 ]]

# %%
#Visualization of Exponential Distribution
sns.distplot(random.exponential(size=1000), hist=False, label='exponential 1-D')
sns.distplot(random.exponential(size=(2,3,5)), hist=False, label='exponential 2-D')
plt.show()
# Out:
# <ipython-input-122-cf86054edfaf>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(size=1000), hist=False, label='exponential 1-D')
# <ipython-input-122-cf86054edfaf>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ##Relation Between Poisson and Exponential Distribution
# Poisson distribution deals with number of occurences of an event in a time period whereas exponential distribution deals with the time between these events.

# %% [markdown]
# #Chi Square Distribution
# Chi Square distribution is used as a basis to verify the hypothesis.
#
# It has two parameters:
#
# df - (degree of freedom).
#
# size - The shape of the returned array.

# %%
x = random.chisquare(df=2, size=(2, 3))

print(x)
# Out:
# [[5.96190142 0.62954604 0.2458978 ]
#  [0.37552536 2.76377207 3.00384859]]

# %%
sns.distplot(random.chisquare(df=1, size=1000), hist=False)

plt.show()
# Out:
# <ipython-input-124-1befd9775b64>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=1, size=1000), hist=False)

# %% [markdown]
# #Rayleigh Distribution
# Rayleigh distribution is used in signal processing.
#
# It has two parameters:
#
# scale - (standard deviation) decides how flat the distribution will be default 1.0).
#
# size - The shape of the returned array.

# %%
x = random.rayleigh(scale=2, size=(2, 3))
print(x)
# Out:
# [[5.29807433 1.74695438 1.72794147]
#  [2.9004467  1.51714107 2.85597473]]

# %%
sns.displot(random.rayleigh(size=100))

plt.show()

# %% [markdown]
# #Pareto Distribution
# A distribution following Pareto's law i.e. 80-20 distribution (20% factors cause 80% outcome).
#
# It has two parameter:
#
# a - shape parameter.
#
# size - The shape of the returned array.

# %%
x = random.pareto(a=2, size=(2, 3))

print(x)
# Out:
# [[3.7352105  0.94496988 0.19157084]
#  [0.42953178 0.38778977 0.10264633]]

# %%
sns.displot(random.pareto(a=50, size=1000))

plt.show()

# %% [markdown]
# #Zipf Distribution
# Zipf distributions are used to sample data based on zipf's law.
#
# It has two parameters:
#
# a - distribution parameter.
#
# size - The shape of the returned array.

# %%
x = random.zipf(a=2, size=(2, 3))

print(x)
# Out:
# [[ 2  1  4]
#  [21  1  1]]

# %%
x = random.zipf(a=2, size=1000)
sns.displot(x[x<10])

plt.show()
